# %%
import numpy as np
import matplotlib.pyplot as plt

import os
while os.path.split(os.getcwd())[1] != "unrolling":
    os.chdir("..")
    if os.getcwd() == "/":
        raise ValueError()
print("Current working directory: {}".format(os.getcwd()))

import sys
PATH ='./codes/'
sys.path.insert(1,PATH)

import pandas as pd
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
# Out:
# Current working directory: /feynman/work/dedip/lilas/wf274757/unrolling

# %%
y_key = 'ptl/val_loss'
training = "LFBS_L4_a2"
log_dir = "./CKPT/lightning_logs0525/"+training
event_accumulator = EventAccumulator(log_dir)
event_accumulator.Reload()
val_loss = [x.value for x in event_accumulator.Scalars(y_key)]
plt.semilogy(val_loss, label=training)

for training in ["LFBS_L3_a22",
                 "LFBS_L4_a22"]:
    log_dir = "./CKPT/lightning_logs0525/"+training
    event_accumulator = EventAccumulator(log_dir)
    event_accumulator.Reload()
    val_loss = [x.value for x in event_accumulator.Scalars(y_key)]
    plt.semilogy(val_loss, label=training)
plt.legend()

# %%
event_accumulator.scalars.Keys()
# Out:
# ['loss/val_loss',
#  'err_x/validation',
#  'err_a/validation',
#  'amplitudes/a1_max_val',
#  'amplitudes/a1_mean_val',
#  'amplitudes/a2_max_val',
#  'amplitudes/a2_mean_val',
#  'amplitudes/a3_max_val',
#  'amplitudes/a3_mean_val',
#  'layer_loss/layer1',
#  'layer_loss/layer2',
#  'layer_loss/layer3',
#  'layer_loss/layer4',
#  'layer_loss/layer5',
#  'layer_loss/layer6',
#  'epoch',
#  'loss/training_loss',
#  'err_x/training',
#  'err_a/training',
#  'amplitudes/a1_max_train',
#  'amplitudes/a1_mean_train',
#  'amplitudes/a2_max_train',
#  'amplitudes/a2_mean_train',
#  'amplitudes/a3_max_train',
#  'amplitudes/a3_mean_train']

# %%
os.walk("./CKPT/lightning_logs/")
# Out:
# <generator object _walk at 0x7fff740b8d30>

# %%
list_dir = ["GLPALM_LS_CNN_L6_sigma0.1",
            "GLPALM_LS_CNN_L7_sigma0.1",
            "GLPALM_LS_CNN_L8_sigma0.1"]
plt.figure(figsize=(18,6))

plt.subplot(121)
y_key = 'err_x/training'

for training in list_dir:
    log_dir = "./CKPT/lightning_logs/"+training
    event_accumulator = EventAccumulator(log_dir)
    event_accumulator.Reload()
    val_loss = [x.value for x in event_accumulator.Scalars(y_key)]
    plt.semilogy(val_loss, label=training)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('NMSE')
plt.title('Training loss')

plt.subplot(122)
y_key = 'err_x/validation'

for training in list_dir:
    log_dir = "./CKPT/lightning_logs/"+training
    event_accumulator = EventAccumulator(log_dir)
    event_accumulator.Reload()
    val_loss = [x.value for x in event_accumulator.Scalars(y_key)]
    plt.semilogy(val_loss, label=training)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('NMSE')
plt.title('Validation loss')
plt.show()

# %%
list_dir = ["GLPALM_LS_CNN_L8_sigmainf"]
plt.figure(figsize=(18,6))

plt.subplot(121)
y_key = 'err_x/training'

for training in list_dir:
    log_dir = "./CKPT/lightning_logs/"+training
    event_accumulator = EventAccumulator(log_dir)
    event_accumulator.Reload()
    val_loss = [x.value for x in event_accumulator.Scalars(y_key)]
    plt.semilogy(val_loss, label=training)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('NMSE')
plt.title('Training loss')

plt.subplot(122)
y_key = 'err_x/validation'

for training in list_dir:
    log_dir = "./CKPT/lightning_logs/"+training
    event_accumulator = EventAccumulator(log_dir)
    event_accumulator.Reload()
    val_loss = [x.value for x in event_accumulator.Scalars(y_key)]
    plt.semilogy(val_loss, label=training)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('NMSE')
plt.title('Validation loss')
plt.show()
